# %%
# importing required modules 
import matplotlib.pyplot as plt 
import numpy as np 
plt.style.use('ggplot')
import pandas as pd
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 13})

# %%
# dataset
data = pd.read_csv("../daily_report/daily_covid_kenya.csv",index_col=0)

# %%
# sample latest data points
data.head()
# Out:
#             confirmed_cases  total_dead  recovered  active_cases
# 05-20-2020             1029          50        366           613
# 05-19-2020              963          50        358           555
# 05-18-2020              912          50        336           526
# 05-17-2020              887          50        313           524
# 05-16-2020              830          50        301           479

# %%
# ordering the data
data = data.iloc[::-1]

# %%
data.plot(title="Covid-19 Kenya's Trend (Created by DataPivotAfrica)",linewidth=2, marker="o")
