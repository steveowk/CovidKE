# %%
# importing required modules 
import matplotlib.pyplot as plt 
import numpy as np 
plt.style.use('ggplot')
import pandas as pd
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 14})

# %%
# dataset
data = pd.read_csv("../daily_report/dailyKE.csv",index_col=0)

# %%
# sample latest data points
data.head()
# Out:
#             confirmed_cases  total_dead  recovered  active
# 05-15-2020              781          45        284     452
# 05-14-2020              758          42        284     432
# 05-13-2020              737          40        281     416
# 05-12-2020              715          36        259     420
# 05-11-2020              700          33        251     416

# %%
# ordering the data
data = data.iloc[::-1]

# %%
data.plot(title="Covid-19KE Progress",linewidth=3)
